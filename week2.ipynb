# %% [markdown]
# <a href="https://colab.research.google.com/github/mahe62/PVCK_genap_2021/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive. mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/P2/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/P2/kitten01.jpg', cv.IMREAD_GRAYSCALE) 
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150), color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300), color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100), radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts=vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
plt.figure(figsize=(6,6))
plt.imshow(img3)

# %%
img6 = img3
img6[:,:,0] = np.zeros([img6.shape[0], img6.shape[1]])
plt.imshow(img6)

# %%
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img7 = img3
img7[:,:,2] = np.zeros([img7.shape[0], img7.shape[1]])
plt.imshow(img7)

# %%
plt.imshow(img[10:100,10:100])

# %%
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img8 = img3[5:30]
img8[:,:,0]=0
img8[:,:,2]=0
plt.imshow(img8)

# %%
import random

black_img3 = np.zeros(shape=(512,512,3),dtype=np.int32)
for x in range(5):
  aw = random.randint(0,600)
  ak = random.randint(0,600)
  
  color = (random.randint(0,255),random.randint(0,255),random.randint(0,255))
  black_img3 = cv.rectangle(black_img3, (aw , aw), (ak, ak), color, thickness =2) 
    
plt.imshow(black_img3)

# %%
img= cv.imread('/content/drive/MyDrive/PCVK/P2/kitten01.jpg')
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img_flip = cv.flip(img3,0)
plt.imshow(img_flip)

# %%
img11= cv.imread('/content/drive/MyDrive/PCVK/P2/mul.jpg')
img11 = cv.cvtColor(img11, cv.COLOR_BGR2RGB)
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111)
cv.rectangle(img11,pt1=(180,430),pt2=(375,600),color=(0,255,0), thickness=2)
cv.circle(img11,center=(277,516),radius=100,color=(255,0,0),thickness=2)

plt.imshow(img11)

# %%
img2 =img 
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img12 = img3[:,:,2]
cv.rectangle(img3,pt1=(0,627),pt2=(100,500),color=(255,255,255),thickness=10)
img12 = img3[:,:,2]
plt.imshow(img12)

# %%
img2 =img 
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img13=img3
font = cv.FONT_HERSHEY_TRIPLEX
cv.putText(img13,text='kitten01',org=(50,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(img13)
